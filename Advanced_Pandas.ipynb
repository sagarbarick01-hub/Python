# %% [markdown]
# # Advanced Pandas Assignment
#
# **Dataset:** `Advanced_pandas_sales_dataset.csv`
#
# This notebook contains:
# - Question statement
# - Python code
# - Output cells
# - Insights for each required question

# %% [markdown]
# ## Dataset Upload / Load
#
# Upload the dataset file into Google Colab before running this notebook.

# %%
import pandas as pd

df = pd.read_csv("Advanced_pandas_sales_dataset.csv")
df.head()

# %% [markdown]
# ## Q1. Dataset Exploration
#
# Perform the following exploratory steps:
# - Display the first 10 rows
# - Display the dataset structure using `info()`
# - Find the number of rows and columns
# - Identify the data types of each column

# %%
# Display the first 10 rows
df.head(10)

# %%
# Display dataset structure
df.info()

# %%
# Number of rows and columns
df.shape

# %%
# Data types of each column
df.dtypes

# %% [markdown]
# ### Q1 Output Summary
#
# - Number of rows and columns: **(230, 11)**
#
# Data types:
#
# ```text
# Order_ID        int64
# Order_Date     object
# Customer       object
# City           object
# Region         object
# Product        object
# Category       object
# Sales           int64
# Quantity        int64
# Discount      float64
# Profit        float64
# ```

# %% [markdown]
# ## Q2. Sales Filtering Analysis
#
# Filter the dataset to display:
# 1. Orders where Sales > 3500
# 2. Orders where Region = "East" and Sales > 2500
#
# Explain the insights observed.

# %%
# Orders where Sales > 3500
df[df["Sales"] > 3500]

# %%
# Orders where Region is East and Sales > 2500
df[(df["Region"] == "East") & (df["Sales"] > 2500)]

# %% [markdown]
# ### Q2 Output / Insight
#
# - Number of orders where Sales > 3500: **104**
# - Number of East region orders where Sales > 2500: **48**
#
# **Insight:** The East region has many high-value orders, showing strong sales performance. Some high-sales orders also include discounts, so profit should also be checked before deciding business performance.

# %% [markdown]
# ## Q3. Customer Purchase Analysis
#
# Identify the top 5 customers based on total sales.

# %%
top_5_customers = df.groupby("Customer")["Sales"].sum().sort_values(ascending=False).head(5)
top_5_customers

# %% [markdown]
# ### Q3 Output
#
# ```text
# Customer
# Nitin    59820
# Raj      58416
# Rahul    52291
# Dev      48500
# Isha     46818
# ```
#
# **Insight:** Nitin is the top customer based on total sales.

# %% [markdown]
# ## Q4. Regional Sales Performance
#
# Calculate the total sales generated by each region. Identify which region generated the highest revenue.

# %%
regional_sales = df.groupby("Region")["Sales"].sum().sort_values(ascending=False)
regional_sales

# %% [markdown]
# ### Q4 Output
#
# ```text
# Region
# East     232675
# South    183108
# West     170227
# North    158210
# ```
#
# **Highest Revenue Region:** **East** with sales of **232675**.

# %% [markdown]
# ## Q5. Product Performance Analysis
#
# Calculate the total quantity sold for each product. Identify the most popular product.

# %%
product_quantity = df.groupby("Product")["Quantity"].sum().sort_values(ascending=False)
product_quantity

# %% [markdown]
# ### Q5 Output
#
# ```text
# Product
# Monitor       156
# Phone         151
# Tablet        150
# Laptop        140
# Mouse         122
# Headphones    115
# Keyboard      110
# Printer       108
# ```
#
# **Most Popular Product:** **Monitor** with quantity sold of **156**.

# %% [markdown]
# ## Q6. Multi-Level Grouping
#
# Group the dataset by Region and Category. Calculate total sales for each combination and write insights.

# %%
region_category_sales = df.groupby(["Region", "Category"])["Sales"].sum()
region_category_sales

# %% [markdown]
# ### Q6 Output
#
# ```text
# Region  Category
# East    Accessories     57646
#         Electronics    160907
#         Office          14122
# North   Accessories     62052
#         Electronics     70023
#         Office          26135
# South   Accessories     80914
#         Electronics     86690
#         Office          15504
# West    Accessories     64811
#         Electronics     84128
#         Office          21288
# ```
#
# **Insight:** Electronics generates the highest sales in the East region. Accessories perform strongly in South and West. Office category has comparatively lower sales than Electronics and Accessories.

# %% [markdown]
# ## Q7. Pivot Table Creation
#
# Create a pivot table showing:
# - Rows → Region
# - Columns → Product
# - Values → Total Sales
#
# Identify which region sells the most laptops.

# %%
sales_pivot = pd.pivot_table(
    df,
    values="Sales",
    index="Region",
    columns="Product",
    aggfunc="sum"
)

sales_pivot

# %%
# Region selling the most laptops
sales_pivot["Laptop"].idxmax()

# %% [markdown]
# ### Q7 Output
#
# Pivot table:
#
# ```text
# Product  Headphones  Keyboard  Laptop  Monitor  Mouse  Phone  Printer  Tablet
# Region
# East          23899     10845   55568    31299  22902  39667    14122   34373
# North         15450     20538    4540    14922  26064  30535    26135   20026
# South         24111     23480   23029    19167  33323  18218    15504   26276
# West          17159     38499   10826    18178   9153  27850    21288   27274
# ```
#
# **Region selling the most laptops:** **East**.

# %% [markdown]
# ## Q8. Profitability Analysis
#
# Calculate the average profit for each product category. Identify the most profitable category.

# %%
category_profit = df.groupby("Category")["Profit"].mean().sort_values(ascending=False)
category_profit

# %%
# Most profitable category
category_profit.idxmax()

# %% [markdown]
# ### Q8 Output
#
# ```text
# Category
# Office         471.94
# Accessories    410.60
# Electronics    396.46
# ```
#
# **Most Profitable Category:** **Office** with average profit of **471.94**.

# %% [markdown]
# ## Q9. Discount Impact Study
#
# Analyze the relationship between discount and profit:
# - Calculate average profit for each discount level
# - Identify whether higher discounts lead to lower profit

# %%
discount_profit = df.groupby("Discount")["Profit"].mean()
discount_profit

# %% [markdown]
# ### Q9 Output
#
# ```text
# Discount
# 0.00    751.21
# 0.05    531.37
# 0.10    346.46
# 0.15    237.19
# 0.20     90.03
# ```
#
# **Insight:** Higher discounts lead to lower average profit. The average profit is highest when discount is 0.00 and lowest when discount is 0.20.

# %% [markdown]
# ## Q10. End-to-End Data Wrangling Task
#
# Perform the following workflow:
# 1. Filter the dataset where Sales > 3000
# 2. Group data by Region and Product
# 3. Calculate total sales
# 4. Reshape the result into a pivot table
# 5. Explain the business insights

# %%
# Step 1: Filter data where Sales > 3000
filtered_df = df[df["Sales"] > 3000]

# Step 2 and 3: Group by Region and Product and calculate total sales
grouped_sales = filtered_df.groupby(["Region", "Product"])["Sales"].sum().reset_index()

# Step 4: Reshape into pivot table
final_pivot = grouped_sales.pivot(index="Region", columns="Product", values="Sales")

final_pivot

# %% [markdown]
# ### Q10 Output
#
# ```text
# Product  Headphones  Keyboard  Laptop  Monitor  Mouse  Phone  Printer  Tablet
# Region
# East          14469      9642   44096    16420  19000  29500     3696   29229
# North          5326     15653    4540     5087  22209  24670    17185    3392
# South         10026     19249   17950    14921  26928  18218    14143   19613
# West          13898     33380    5922    14354   3511  15653    12648   17185
# ```
#
# ### Business Insights
#
# - East is the strongest region for high-value sales.
# - East performs very well in Laptop, Phone, and Tablet sales.
# - West performs strongly in Keyboard sales.
# - South performs well in Mouse and Accessories-related sales.
# - The company should focus on high-performing products in each region and control discount levels to protect profit.
